# %%
import pandas as pd

# %%
df = pd.read_csv("./shipping_logs.csv")

# %%
df.head()
# Out:
#    Order ID Shipping Date              Carrier  Tracking Number  Latitude  \
# 0      2000    2025-06-20   SummitLine Express        126855092   35.8926
# 1      2001    2025-06-26   SummitLine Express        362950628   35.7424
# 2      2002    2025-05-27    PeakPath Shipping        890779946   34.5403
# 3      2003    2025-05-20  SwiftWing Logistics        895285932   43.5412
# 4      2004    2025-07-05    PeakPath Shipping        193349856   37.7475
#
#    Longitude      Status  Delivery Days   Late
# 0    71.5447   Delivered            3.0  False
# 1    71.3143   Delivered           10.0   True
# 2   -97.5455   Delivered           10.0   True
# 3    64.8811  In Transit            NaN    NaN
# 4    31.7983  In Transit            NaN    NaN

# %%
df2 = pd.read_csv("./customer_reviews.csv")

# %%
df2.head()
# Out:
#    ORDER_ID                  PRODUCT        DATE  \
# 0      1001              Alpine Skis  2023-10-05
# 1      1002           Thermal Gloves  2023-10-08
# 2      1003  Performance Racing Skis  2023-10-11
# 3      1004         Insulated Jacket  2023-10-11
# 4      1005              Ski Goggles  2023-10-11
#
#                                              SUMMARY  SENTIMENT_SCORE
# 0  After testing Alpine Skis in Colorado, Utah, a...         0.863603
# 1  The author tested Thermal Gloves in extreme wi...         0.685061
# 2  The author, an experienced ski racer, evaluate...         0.767007
# 3  The author subjected an insulated jacket to ex...         0.524575
# 4  The author extensively tested ski goggles in v...         0.786815
